# %%
#all data virtulization

# %%
(2093*100)/2826
# Out:
# 74.0622788393489

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cars=pd.read_csv("cars-1 (2).csv")

# %%
cars.head()
# Out:
#     mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0  14.0          8         350  165      4209          12  1972       US.
# 1  31.9          4          89   71      1925          14  1980   Europe.
# 2  17.0          8         302  140      3449          11  1971       US.
# 3  15.0          8         400  150      3761          10  1971       US.
# 4  30.5          4          98   63      2051          17  1978       US.

# %%
cars["brand"].unique()
# Out:
# array([' US.', ' Europe.', ' Japan.'], dtype=object)

# %%
filter1=cars['brand']==' US.'
cars1=cars[filter1]
cars1.shape
# Out:
# (162, 8)

# %%
filter2=cars['brand']==' Europe.'
cars2=cars[filter2]
cars2.shape
# Out:
# (48, 8)

# %%
filter3=cars['brand']==' Japan.'
cars3=cars[filter3]
cars3.shape
# Out:
# (51, 8)

# %%
data={' US.':162,' Europe.':48,' Japan.':51}
names=list(data.keys())
values=list(data.values())
fig=plt.figure(figsize=(10,5))
ax1=plt.subplot()
ax1.bar(names,values)
plt.show()

# %%
ax1=plt.subplot()
sns.countplot(x='brand',data=cars,hue='brand',ax=ax1)
plt.show()

# %%
ax1=plt.subplot()
sns.countplot(y='brand',data=cars,hue='brand',ax=ax1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ax1=plt.subplot()
#       2 sns.countplot(y='brand',data=cars,hue='brand',ax=ax1)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
cars.dtypes
# Out:
# mpg            float64
# cylinders        int64
# cubicinches     object
# hp               int64
# weightlbs       object
# time-to-60       int64
# year             int64
# brand           object
# dtype: object

# %%
ax1=plt.subplot()
sns.countplot(x='brand',data=cars,hue='year',ax=ax1)
plt.show()

# %%
data=[
    [90,85,15],
    [78,9,25],
    [90,45,35]
    
]
sns.heatmap(data,annot=True)
# Out:
# <Axes: >

# %%
ax1=plt.subplot()
sns.countplot(x='brand',data=cars,hue='brand',ax=ax1,
              palette=['red','green','y'])
plt.show()

# %%
ax1=plt.subplot()
sns.countplot(x='brand',data=cars,hue='brand',ax=ax1,
              palette='Blues')
plt.show()

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
cars
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
fig=plt.figure(figsize=(12,12))
ax1=plt.subplot(2,2,1)
sns.scatterplot(x='hp',y='mpg',data=cars,ax=ax1,hue='brand')
plt.title("MPG VS HP")
plt.xlabel("HP")
plt.ylabel("MPG")


ax2=plt.subplot(2,2,2)
sns.scatterplot(x='hp',y='time-to-60',data=cars,ax=ax2,hue='brand')
plt.title("MPG VS time-to-60")
plt.xlabel("HP")
plt.ylabel('title-to-60')


ax3=plt.subplot(2,2,3)
sns.scatterplot(x='hp',y='weightlbs',data=cars,ax=ax3,hue='brand')
plt.title("MPG VS weightlbs")
plt.xlabel("HP")
plt.ylabel('Hp Vs Weight')

ax4=plt.subplot(2,2,4)
sns.scatterplot(x='hp',y='cylinders',data=cars,ax=ax4,hue='brand')
plt.title("MPG VS cylinders")
plt.xlabel("HP")
plt.ylabel('cylinders')


plt.show()

# %%
data.brand.count()
# Out:
# 261

# %%
cars=data

# %%
fig=plt.figure(figsize=(30,18))
ax1=plt.subplot(3,3,1)
sns.barplot(x='cylinders',y='hp',data=data,ax=ax1)
plt.title("Cylinders Vs Hp")
plt.xlabel("cylender")
plt.ylabel('hp')

ax2=plt.subplot(3,3,2)
sns.barplot(x='cylinders',y='mpg',data=data,ax=ax2)
plt.title("Cylinders Vs miles per gallon")
plt.xlabel('cylinder')
plt.ylabel('mpg')


ax3=plt.subplot(3,3,3)
sns.barplot(x='cylinders',y='weightlbs',data=data,ax=ax3)
plt.title("Cylinders Vs weightlb")

ax4=plt.subplot(3,3,4)
sns.barplot(x='year',y='time-to-60',data=data,ax=ax4)
plt.title("Cylinders Vs Hp")
plt.xlabel('year')
plt.ylabel('time-60-60')

ax5=plt.subplot(3,3,5)
sns.barplot(x='year',y='mpg',data=data,ax=ax5)
plt.title("year vs mpg")
plt.xlabel('year')
plt.ylabel('mpg')


ax6=plt.subplot(3,3,6)
sns.barplot(x='year',y='hp',data=data,ax=ax6)
plt.title("year Vs Hp")
plt.xlabel('year')
plt.ylabel('hp')

plt.show()

# %%
fig=plt.figure(figsize=(5,5))
ax1=plt.subplot(1,1,1)
sns.countplot(x='brand',data=data)
plt.show()

# %%
fig=plt.figure(figsize=(10,10))
ax1=plt.subplot(2,2,1)
sns.boxplot(x='hp',data=data,ax=ax1)
plt.xlabel('hp')

ax2=plt.subplot(2,2,2)
sns.boxplot(x='mpg',data=data,ax=ax2)
plt.xlabel('mpg')

ax3=plt.subplot(2,2,3)
sns.boxplot(x='time-to-60',data=data,ax=ax3)
plt.xlabel('time-to-60')

ax4=plt.subplot(2,2,4)
sns.boxplot(x='weightlbs',data=data,ax=ax4)
plt.xlabel('weightlbs')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 fig=plt.figure(figsize=(10,10))
#       2 ax1=plt.subplot(2,2,1)
# ----> 3 sns.boxplot(x='hp',data=data,ax=ax1)
#       4 plt.xlabel('hp')
#       6 ax2=plt.subplot(2,2,2)
#
# NameError: name 'data' is not defined
