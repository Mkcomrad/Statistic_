# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('country_profile_variables (1).csv')

# %%
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
df.head(50)
# Out:
#                              country             Region Surface area (km2)  \
# 0                        Afghanistan       SouthernAsia             652864
# 1                            Albania     SouthernEurope              28748
# 2                            Algeria     NorthernAfrica            2381741
# 3                     American Samoa          Polynesia                199
# 4                            Andorra     SouthernEurope                468
# 5                             Angola       MiddleAfrica            1246700
# 6                           Anguilla          Caribbean                 91
# 7                Antigua and Barbuda          Caribbean                442
# 8                          Argentina       SouthAmerica            2780400
# 9                            Armenia        WesternAsia              29743
# 10                             Aruba          Caribbean                180
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (229, 50)

# %%
df.size
# Out:
# 11450

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
#data cleaning

df.isnull().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# Length: 229, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina',
#        'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus',
#        'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia (Plurinational State of)',
#        'Bonaire, Sint Eustatius and Saba', 'Bosnia and Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Channel Islands', 'Chile',
#        'China, Hong Kong SAR', 'China, Macao SAR', 'China', 'Colombia',
#        'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', 'Croatia',
#        'Cuba', 'Cyprus', 'Czechia',
#        "Democratic People's Republic of Korea",
# ...

# %%
df['country'].value_counts()
# Out:
# Afghanistan      1
# New Caledonia    1
# Nicaragua        1
# Niger            1
# Nigeria          1
#                 ..
# Gibraltar        1
# Greece           1
# Greenland        1
# Grenada          1
# Zimbabwe         1
# Name: country, Length: 229, dtype: int64

# %% [markdown]
# # Let's perform the stats topics

# %%
#Central tendencies
mean
median
mode
#variation
range
percentile
quartiles
IQR
variance
Standard deviation


#Co-relation
#probabilty

# %%
#central tendency
sum(df['Population in thousands (2017)'])/len(df['Population in thousands (2017)'])
# Out:
# 32756.794759825327

# %%
df['Population in thousands (2017)'].mean()
# Out:
# 32756.794759825327

# %%
df1=df['Population in thousands (2017)'].sort_values().reset_index()

# %%
n=229
df1
# Out:
#      index  Population in thousands (2017)
# 0      204                               1
# 1       91                               1
# 2      149                               2
# 3       68                               3
# 4      169                               4
# ..     ...                             ...
# 224     28                          209288
# 225     96                          263991
# 226    217                          324460
# 227     95                         1339180
# 228     45                         1409517
#
# [229 rows x 2 columns]

# %%
(n+1)/2
# Out:
# 115.0

# %%
df['Population in thousands (2017)'].median()
# Out:
# 5448.0

# %%
df1.loc[114,'Population in thousands (2017)']
# Out:
# 5448

# %%
df['Population in thousands (2017)'].value_counts().head(10)
# Out:
# 2890    2
# 55      2
# 11      2
# 56      2
# 276     2
# 2930    2
# 1       2
# 108     2
# 283     2
# 105     2
# Name: Population in thousands (2017), dtype: int64

# %%
df['Population in thousands (2017)'].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
df.mean()
# Out:
# C:\Users\HP1\AppData\Local\Temp\ipykernel_20820\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Population in thousands (2017)                            32756.794760
# Population density (per km2, 2017)                          462.824891
# Sex ratio (m per 100 f, 2017)                               100.202183
# GDP: Gross domestic product (million current US$)        321433.886463
# GDP per capita (current US$)                              14251.877729
# Economy: Industry (% of GVA)                                 15.958952
# Economy: Services and other activity (% of GVA)              46.408734
# Agricultural production index (2004-2006=100)                99.270742
# ...

# %%
df.median()
# Out:
# C:\Users\HP1\AppData\Local\Temp\ipykernel_20820\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Population in thousands (2017)                            5448.0
# Population density (per km2, 2017)                          88.1
# Sex ratio (m per 100 f, 2017)                               99.0
# GDP: Gross domestic product (million current US$)        16251.0
# GDP per capita (current US$)                              4836.1
# Economy: Industry (% of GVA)                                25.5
# Economy: Services and other activity (% of GVA)             59.5
# Agricultural production index (2004-2006=100)              111.0
# Food production index (2004-2006=100)                      112.0
# ...

# %%
df.mode()
# Out:
#                        country     Region Surface area (km2)  \
# 0                  Afghanistan  Caribbean                -99
# 1                      Albania        NaN                NaN
# 2                      Algeria        NaN                NaN
# 3               American Samoa        NaN                NaN
# 4                      Andorra        NaN                NaN
# ..                         ...        ...                ...
# 224  Wallis and Futuna Islands        NaN                NaN
# 225             Western Sahara        NaN                NaN
# 226                      Yemen        NaN                NaN
# 227                     Zambia        NaN                NaN
# 228                   Zimbabwe        NaN                NaN
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                               1.0                                 4.0
# 1                              11.0                                 NaN
# ...

# %%
df.mean(numeric_only=True)
# Out:
# Population in thousands (2017)                            32756.794760
# Population density (per km2, 2017)                          462.824891
# Sex ratio (m per 100 f, 2017)                               100.202183
# GDP: Gross domestic product (million current US$)        321433.886463
# GDP per capita (current US$)                              14251.877729
# Economy: Industry (% of GVA)                                 15.958952
# Economy: Services and other activity (% of GVA)              46.408734
# Agricultural production index (2004-2006=100)                99.270742
# Food production index (2004-2006=100)                       100.043668
# Urban population (% of total population)                     59.508734
# Health: Total expenditure (% of GDP)                        -11.248908
# Seats held by women in national parliaments %                 1.861572
# Individuals using the Internet (per 100 inhabitants)        198.711790
# ...

# %%
#variation

# %%
#range
max1=df['Population in thousands (2017)'].max()
max1
# Out:
# 1409517

# %%
min1=df['Population in thousands (2017)'].min()
min1
# Out:
# 1

# %%
Range=max1-min1
Range
# Out:
# 1409516

# %%
#percentiles
df['Population in thousands (2017)'].quantile(0.90)
# Out:
# 57720.00000000004

# %%
df['Population in thousands (2017)'].quantile(0.20)
# Out:
# 233.40000000000006

# %%
df['Population in thousands (2017)'].quantile(0.50)
# Out:
# 5448.0

# %%
q1=df['Population in thousands (2017)'].quantile(0.25)
q2=df['Population in thousands (2017)'].quantile(0.50)
q3=df['Population in thousands (2017)'].quantile(0.75)

# %%
q1,q2,q3
# Out:
# (431.0, 5448.0, 19193.0)

# %%
#check at which position 2090 is lies

# %%
len(df[df['Population in thousands (2017)']<=2890]) &
# Out:
# 92

# %%
len(df)
# Out:
# 229

# %%
(92/229)*100
# Out:
# 40.174672489082965

# %%
#IQR Enterquantile range
IQR=q3-q1
IQR
# Out:
# 18762.0

# %%
plt.boxplot(df['Individuals using the Internet (per 100 inhabitants)'])
plt.show()

# %%
Q1=df['Individuals using the Internet (per 100 inhabitants)'].quantile(0.25)
Q3=df['Individuals using the Internet (per 100 inhabitants)'].quantile(0.75)

# %%
Q1,Q3
# Out:
# (55.0, 196.0)

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 141.0

# %%
plt.boxplot(df['Individuals using the Internet (per 100 inhabitants)'])
plt.show()

# %%
#upper fence and lower fence
uf=Q3+1.5*IQR
lf=Q1-1.5*IQR

# %%
uf,lf
# Out:
# (407.5, -156.5)

# %%
df=df[(df['Individuals using the Internet (per 100 inhabitants)']>=lf) & (df['Individuals using the Internet (per 100 inhabitants)']<=uf)]
df
# Out:
#                        country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
plt.boxplot(df['Individuals using the Internet (per 100 inhabitants)'])
plt.show()

# %%
#variance

# %%
v1=df['Individuals using the Internet (per 100 inhabitants)'].var()

# %%
v1
# Out:
# 8494.338833094209

# %%
s1=df['Individuals using the Internet (per 100 inhabitants)'].std()
s1
# Out:
# 92.16473747097753

# %%
np.sqrt(v1)
# Out:
# 92.16473747097753

# %%
#co Relation

# %%
df1=df[['Individuals using the Internet (per 100 inhabitants)','Population in thousands (2017)']]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 228
# Data columns (total 2 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Individuals using the Internet (per 100 inhabitants)  205 non-null    int64
#  1   Population in thousands (2017)                        205 non-null    int64
# dtypes: int64(2)
# memory usage: 4.8 KB

# %%
df1.corr()
# Out:
#                                                     Individuals using the Internet (per 100 inhabitants)  \
# Individuals using the Internet (per 100 inhabit...                                           1.000000
# Population in thousands (2017)                                                               0.403348
#
#                                                     Population in thousands (2017)
# Individuals using the Internet (per 100 inhabit...                        0.403348
# Population in thousands (2017)                                            1.000000
